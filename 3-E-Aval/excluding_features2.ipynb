# %%
import pandas as pd

# Read both datasets
df_mw = pd.read_csv('/Users/marcelosilva/Desktop/clustering(0-4)/3-E-Aval/DSWOUTMW.csv')
df = pd.read_csv('/Users/marcelosilva/Desktop/clustering(0-4)/3-E-Aval/DSWOUTNS.csv')

# Get column names for both datasets
cols_mw = set(df_mw.columns)
cols_ns = set(df_ns.columns)

# Find differences
removed_cols = cols_mw - cols_ns
added_cols = cols_ns - cols_mw

print("Columns in DSWOUTMW but not in DSWOUTNS (removed):")
for col in removed_cols:
    print(f"- {col}")

print("\nColumns in DSWOUTNS but not in DSWOUTMW (added):")
for col in added_cols:
    print(f"- {col}")

print(f"\nTotal columns in DSWOUTMW: {len(cols_mw)}")
print(f"Total columns in DSWOUTNS: {len(cols_ns)}")
# Out:
# Columns in DSWOUTMW but not in DSWOUTNS (removed):
# - e219a_nao_sabe
#
# Columns in DSWOUTNS but not in DSWOUTMW (added):
#
# Total columns in DSWOUTMW: 50
# Total columns in DSWOUTNS: 49

# %%
import pandas_utils as pdu

pdu.custom_info(df)
# Out:
# DataFrame Info with Completeness Analysis:
# ---------------------------------------------------------------------------
# Total Rows: 14558
# Total Columns: 49
#
# Column Details:
# ---------------------------------------------------------------------------
# id_anon                 14558 non-null int64      (100.0% complete)
# e01_leite_peito         14558 non-null object     (100.0% complete)
# e02_agua                14558 non-null object     (100.0% complete)
# e04_agua_com_acucar     12817 non-null object     (88.04% complete) •
# e05_cha                 14558 non-null object     (100.0% complete)
# e06_leite_vaca_po       14558 non-null object     (100.0% complete)
# e07_leite_vaca_liquido    14558 non-null object     (100.0% complete)
# e08_leite_soja_po       14558 non-null object     (100.0% complete)
# e09_leite_soja_liquido    14558 non-null object     (100.0% complete)
# e10_formula_infantil    14558 non-null object     (100.0% complete)
# e11_suco                14558 non-null object     (100.0% complete)
# e12_fruta_inteira       14558 non-null object     (100.0% complete)
# e13_fruta_vezes          6905 non-null float64    (47.43% complete) •
# e16_comida_sal          14558 non-null object     (100.0% complete)
# e17_sal_vezes           11952 non-null float64    (82.1% complete) •
# e18_oferecida           14558 non-null object     (100.0% complete)
# e181_pedacos            11952 non-null object     (82.1% complete) •
# e182_amassada           11952 non-null object     (82.1% complete) •
# e183_peneira            11952 non-null object     (82.1% complete) •
# e184_liquidificada      11952 non-null object     (82.1% complete) •
# e185_caldo              11952 non-null object     (82.1% complete) •
# e189_nao_sabe           11952 non-null object     (82.1% complete) •
# e19_mingau              14558 non-null object     (100.0% complete)
# e20_iogurte             14558 non-null object     (100.0% complete)
# e21_arroz               14558 non-null object     (100.0% complete)
# e211a_pao_frances       14558 non-null object     (100.0% complete)
# e212a_feito_em_casa     14558 non-null object     (100.0% complete)
# e213a_industrializado    14558 non-null object     (100.0% complete)
# e214a_nao_comeu         14558 non-null object     (100.0% complete)
# e21a_pao                14558 non-null object     (100.0% complete)
# e22_legumes             14558 non-null object     (100.0% complete)
# e23_cenoura             14558 non-null object     (100.0% complete)
# e24_couve               14558 non-null object     (100.0% complete)
# e25_verduras            14558 non-null object     (100.0% complete)
# e26_feijao              14558 non-null object     (100.0% complete)
# e27_carne               14558 non-null object     (100.0% complete)
# e28_figado              14558 non-null object     (100.0% complete)
# e29_ovo                 14558 non-null object     (100.0% complete)
# e30_hamburger           14558 non-null object     (100.0% complete)
# e31_salgadinhos         14558 non-null object     (100.0% complete)
# e32_suco_industrializado    14558 non-null object     (100.0% complete)
# e33_refrigerante        14558 non-null object     (100.0% complete)
# e34_macarrao            14558 non-null object     (100.0% complete)
# e35_biscoito            14558 non-null object     (100.0% complete)
# e36_bala                14558 non-null object     (100.0% complete)
# e37_tempero             14558 non-null object     (100.0% complete)
# e38_farinhas            14558 non-null object     (100.0% complete)
# e39_mamadeira           14558 non-null object     (100.0% complete)
# e40_adocado             14558 non-null object     (100.0% complete)
#
# Memory Usage: 5573.1+ KB

# %%
# Análise das respostas únicas em cada variável
print("🔍 ANÁLISE DAS RESPOSTAS ÚNICAS POR VARIÁVEL")
print("=" * 60)

# Lista das variáveis para analisar (excluindo id_anon)
variables_to_analyze = [col for col in df.columns if col != 'id_anon']

for var in variables_to_analyze:
    print(f"\n📊 {var}:")
    
    # Valores únicos e suas contagens
    value_counts = df[var].value_counts(dropna=False)
    
    # Mostra todos os valores únicos
    for value, count in value_counts.items():
        percentage = (count / len(df)) * 100
        print(f"   '{value}': {count:,} ({percentage:.1f}%)")
    
    # Se tiver muitos valores únicos, mostra apenas os mais frequentes
    if len(value_counts) > 10:
        print(f"   ... (mostrando apenas os 10 mais frequentes de {len(value_counts)} valores únicos)")
    
    print(f"   Total de valores únicos: {len(value_counts)}")
    print("-" * 40)

print(f"\n📋 RESUMO GERAL:")
print(f"Total de linhas no dataset: {len(df):,}")
print(f"Total de variáveis analisadas: {len(variables_to_analyze)}")
# Out:
# 🔍 ANÁLISE DAS RESPOSTAS ÚNICAS POR VARIÁVEL
# ============================================================
#
# 📊 e01_leite_peito:
#    'Não': 9,695 (66.6%)
#    'Sim': 4,863 (33.4%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e02_agua:
#    'Sim': 12,817 (88.0%)
#    'Não': 1,741 (12.0%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e04_agua_com_acucar:
#    'Não': 12,697 (87.2%)
#    'nan': 1,741 (12.0%)
#    'Sim': 120 (0.8%)
#    Total de valores únicos: 3
# ----------------------------------------
#
# 📊 e05_cha:
#    'Não': 13,851 (95.1%)
#    'Sim': 707 (4.9%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e06_leite_vaca_po:
#    'Não': 10,677 (73.3%)
#    'Sim': 3,881 (26.7%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e07_leite_vaca_liquido:
#    'Não': 9,073 (62.3%)
#    'Sim': 5,485 (37.7%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e08_leite_soja_po:
#    'Não': 14,491 (99.5%)
#    'Sim': 67 (0.5%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e09_leite_soja_liquido:
#    'Não': 14,487 (99.5%)
#    'Sim': 71 (0.5%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e10_formula_infantil:
#    'Não': 13,223 (90.8%)
#    'Sim': 1,335 (9.2%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e11_suco:
#    'Não': 11,430 (78.5%)
#    'Sim': 3,128 (21.5%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e12_fruta_inteira:
#    'Não': 7,653 (52.6%)
#    'Sim': 6,905 (47.4%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e13_fruta_vezes:
#    'nan': 7,653 (52.6%)
#    '1.0': 3,857 (26.5%)
#    '2.0': 2,335 (16.0%)
#    '3.0': 519 (3.6%)
#    '4.0': 137 (0.9%)
#    '5.0': 38 (0.3%)
#    '6.0': 10 (0.1%)
#    '7.0': 5 (0.0%)
#    '8.0': 2 (0.0%)
#    '10.0': 2 (0.0%)
#    Total de valores únicos: 10
# ----------------------------------------
#
# 📊 e16_comida_sal:
#    'Sim': 11,952 (82.1%)
#    'Não': 2,606 (17.9%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e17_sal_vezes:
#    '2.0': 8,472 (58.2%)
#    'nan': 2,606 (17.9%)
#    '1.0': 2,534 (17.4%)
#    '3.0': 860 (5.9%)
#    '4.0': 69 (0.5%)
#    '5.0': 11 (0.1%)
#    '6.0': 6 (0.0%)
#    Total de valores únicos: 7
# ----------------------------------------
#
# 📊 e18_oferecida:
#    'A     ': 9,916 (68.1%)
#    '      ': 2,606 (17.9%)
#    'B     ': 1,130 (7.8%)
#    'AB    ': 368 (2.5%)
#    'D     ': 135 (0.9%)
#    'E     ': 104 (0.7%)
#    'AE    ': 85 (0.6%)
#    'BE    ': 41 (0.3%)
#    'ABE   ': 36 (0.2%)
#    'C     ': 30 (0.2%)
#    'AD    ': 26 (0.2%)
#    'BD    ': 16 (0.1%)
#    'ABC   ': 11 (0.1%)
#    'BC    ': 9 (0.1%)
#    'ABD   ': 8 (0.1%)
#    'BDE   ': 7 (0.0%)
#    'AC    ': 6 (0.0%)
#    'ABCD  ': 5 (0.0%)
#    'DE    ': 5 (0.0%)
#    'ADE   ': 4 (0.0%)
#    'BCE   ': 4 (0.0%)
#    'ABDE  ': 1 (0.0%)
#    'ABCE  ': 1 (0.0%)
#    'BCDE  ': 1 (0.0%)
#    'CE    ': 1 (0.0%)
#    'BCD   ': 1 (0.0%)
#    'ACD   ': 1 (0.0%)
#    ... (mostrando apenas os 10 mais frequentes de 27 valores únicos)
#    Total de valores únicos: 27
# ----------------------------------------
#
# 📊 e181_pedacos:
#    'Sim': 10,468 (71.9%)
#    'nan': 2,606 (17.9%)
#    'Não': 1,484 (10.2%)
#    Total de valores únicos: 3
# ----------------------------------------
#
# 📊 e182_amassada:
#    'Não': 10,313 (70.8%)
#    'nan': 2,606 (17.9%)
#    'Sim': 1,639 (11.3%)
#    Total de valores únicos: 3
# ----------------------------------------
#
# 📊 e183_peneira:
#    'Não': 11,882 (81.6%)
#    'nan': 2,606 (17.9%)
#    'Sim': 70 (0.5%)
#    Total de valores únicos: 3
# ----------------------------------------
#
# 📊 e184_liquidificada:
#    'Não': 11,742 (80.7%)
#    'nan': 2,606 (17.9%)
#    'Sim': 210 (1.4%)
#    Total de valores únicos: 3
# ----------------------------------------
#
# 📊 e185_caldo:
#    'Não': 11,662 (80.1%)
#    'nan': 2,606 (17.9%)
#    'Sim': 290 (2.0%)
#    Total de valores únicos: 3
# ----------------------------------------
#
# 📊 e189_nao_sabe:
#    'Não': 11,952 (82.1%)
#    'nan': 2,606 (17.9%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e19_mingau:
#    'Não': 11,478 (78.8%)
#    'Sim': 3,080 (21.2%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e20_iogurte:
#    'Não': 10,512 (72.2%)
#    'Sim': 4,046 (27.8%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e21_arroz:
#    'Sim': 10,487 (72.0%)
#    'Não': 4,071 (28.0%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e211a_pao_frances:
#    'Não': 9,563 (65.7%)
#    'Sim': 4,995 (34.3%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e212a_feito_em_casa:
#    'Não': 14,108 (96.9%)
#    'Sim': 450 (3.1%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e213a_industrializado:
#    'Não': 13,326 (91.5%)
#    'Sim': 1,232 (8.5%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e214a_nao_comeu:
#    'Sim': 8,045 (55.3%)
#    'Não': 6,513 (44.7%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e21a_pao:
#    'D    ': 8,045 (55.3%)
#    'A    ': 4,843 (33.3%)
#    'C    ': 1,124 (7.7%)
#    'B    ': 387 (2.7%)
#    'AC   ': 96 (0.7%)
#    'AB   ': 51 (0.4%)
#    'BC   ': 7 (0.0%)
#    'ABC  ': 5 (0.0%)
#    Total de valores únicos: 8
# ----------------------------------------
#
# 📊 e22_legumes:
#    'Não': 11,118 (76.4%)
#    'Sim': 3,440 (23.6%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e23_cenoura:
#    'Não': 11,015 (75.7%)
#    'Sim': 3,543 (24.3%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e24_couve:
#    'Não': 13,475 (92.6%)
#    'Sim': 1,083 (7.4%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e25_verduras:
#    'Não': 13,189 (90.6%)
#    'Sim': 1,369 (9.4%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e26_feijao:
#    'Sim': 8,917 (61.3%)
#    'Não': 5,641 (38.7%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e27_carne:
#    'Sim': 9,961 (68.4%)
#    'Não': 4,597 (31.6%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e28_figado:
#    'Não': 14,302 (98.2%)
#    'Sim': 256 (1.8%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e29_ovo:
#    'Não': 12,121 (83.3%)
#    'Sim': 2,437 (16.7%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e30_hamburger:
#    'Não': 12,695 (87.2%)
#    'Sim': 1,863 (12.8%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e31_salgadinhos:
#    'Não': 12,844 (88.2%)
#    'Sim': 1,714 (11.8%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e32_suco_industrializado:
#    'Não': 10,670 (73.3%)
#    'Sim': 3,888 (26.7%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e33_refrigerante:
#    'Não': 12,063 (82.9%)
#    'Sim': 2,495 (17.1%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e34_macarrao:
#    'Não': 13,682 (94.0%)
#    'Sim': 876 (6.0%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e35_biscoito:
#    'Não': 7,535 (51.8%)
#    'Sim': 7,023 (48.2%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e36_bala:
#    'Não': 11,775 (80.9%)
#    'Sim': 2,783 (19.1%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e37_tempero:
#    'Não': 11,518 (79.1%)
#    'Sim': 3,040 (20.9%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e38_farinhas:
#    'Não': 10,706 (73.5%)
#    'Sim': 3,852 (26.5%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e39_mamadeira:
#    'Não': 8,383 (57.6%)
#    'Sim': 6,175 (42.4%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📊 e40_adocado:
#    'Não': 10,003 (68.7%)
#    'Sim': 4,555 (31.3%)
#    Total de valores únicos: 2
# ----------------------------------------
#
# 📋 RESUMO GERAL:
# Total de linhas no dataset: 14,558
# Total de variáveis analisadas: 48
